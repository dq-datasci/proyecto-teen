# %% [markdown]
# # 1. Importando librerías

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

# %% [markdown]
# # 2. Creando una sesión

# %%
spark = SparkSession.builder.master("local").appName("teen").getOrCreate()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/24 15:55:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # 3. Creación de un dataframe básico

# %%
teen_df = spark.read.csv("../data/Teen_Mental_Health_Dataset.csv")

# %% [markdown]
# # 4. Mostrar el dataframe básico

# %%
teen_df.show()
# Out:
# +---+------+--------------------+--------------+-----------+--------------------+--------------------+-----------------+--------------------+------------+-------------+---------------+----------------+
# |_c0|   _c1|                 _c2|           _c3|        _c4|                 _c5|                 _c6|              _c7|                 _c8|         _c9|         _c10|           _c11|            _c12|
# +---+------+--------------------+--------------+-----------+--------------------+--------------------+-----------------+--------------------+------------+-------------+---------------+----------------+
# |age|gender|daily_social_medi...|platform_usage|sleep_hours|screen_time_befor...|academic_performance|physical_activity|social_interactio...|stress_level|anxiety_level|addiction_level|depression_label|
# ...

# %%
spark.stop()
